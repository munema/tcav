# %% [markdown]
# # Running TCAV
#
#
# This notebook walks you through things you need to run TCAV.
#
# Before running this notebook, run the following to download all the data.
#
# ```
# cd tcav/tcav_examples/image_models/imagenet
#
# python download_and_make_datasets.py --source_dir=YOUR_PATH --number_of_images_per_folder=50 --number_of_random_folders=3
# ```
#
# In high level, you need:
#
# 1. **example images in each folder** (you have this if you ran the above)
#  * images for each concept
#  * images for the class/labels of interest
#  * random images that will be negative examples when learning CAVs (images that probably don't belong to any concepts)
# 2. **model wrapper** (below uses example from tcav/model.py)
#  * an instance of  ModelWrapper abstract class (in model.py). This tells TCAV class (tcav.py) how to communicate with your model (e.g., getting internal tensors)
# 3. **act_generator** (below uses example from tcav/activation_generator.py)
#  * an instance of ActivationGeneratorInterface that tells TCAV class how to load example data and how to get activations from the model
#
#
# ## Requirements
#
#     pip install the tcav and tensorflow packages (or tensorflow-gpu if using GPU)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tcav.activation_generator as act_gen
import tcav.cav as cav
import tcav.model  as model
import tcav.tcav as tcav
import tcav.utils as utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import os 
import tensorflow as tf
from config import root_dir, model_to_run, bottlenecks, target, concepts, version, num_random_exp, max_examples

# %% [markdown]
# ## Step 1. Store concept and target class images to local folders
#
# and tell TCAV where they are.
#
# **source_dir**: where images of concepts, target class and random images (negative samples when learning CAVs) live. Each should be a sub-folder within this directory.
#
# Note that random image directories can be in any name. In this example, we are using `random500_0`, `random500_1`,.. for an arbitrary reason.
#
# You need roughly 50-200 images per concept and target class (10-20 pictures also tend to work, but 200 is pretty safe).
#
#
# **cav_dir**: directory to store CAVs (`None` if you don't want to store)
#
# **target, concept**: names of the target class (that you want to investigate) and concepts (strings) - these are folder names in source_dir
#
# **bottlenecks**: list of bottleneck names (intermediate layers in your model) that you want to use for TCAV. These names are defined in the model wrapper below.

# %%
# function to create project name

def list_string(list):
    str = list[0]
    for s in list[1:]:
        str += '_' + s
    return str

def create_project_name(model, bottlenecks, target, concepts, version):
    name = model_to_run
    name += '_'+ list_string(bottlenecks)
    name += ':'+ target
    name += ':'+ list_string(concepts)
    name += '_'+ str(version)
    return name

# %%
print ('REMEMBER TO UPDATE YOUR_PATH (where images, models are)!')
# the name of the parent directory that results are stored (only if you want to cache)
project_name = create_project_name(model_to_run, bottlenecks, target, concepts, version)
working_dir = root_dir + 'log/'  + project_name
# where activations are stored (only if your act_gen_wrapper does so)
activation_dir =  working_dir+ '/activations/'
# where CAVs are stored. 
# You can say None if you don't wish to store any.
cav_dir = working_dir + '/cavs/'
# where CAVs are stored. 
tcav_dir = working_dir + '/tcavs/'
# where the images live. 
source_dir = root_dir + 'tcav/dataset/for_tcav/'
      
utils.make_dir_if_not_exists(activation_dir)
utils.make_dir_if_not_exists(working_dir)
utils.make_dir_if_not_exists(cav_dir)
utils.make_dir_if_not_exists(tcav_dir)

# this is a regularizer penalty parameter for linear classifier to get CAVs. 
alphas = [0.1]   

print('TCAV dataset path is {}'.format(source_dir))
print('Results is saved at {}'.format(working_dir))
# Out:
# REMEMBER TO UPDATE YOUR_PATH (where images, models are)!
# TCAV dataset path is /home/tomohiro/code/tcav/tcav/dataset/for_tcav/
# Results is saved at /home/tomohiro/code/tcav/log/GoogleNet_mixed4c:zebra:dotted_striped_zigzagged_0

# %% [markdown]
# ## Step 2. Write your model wrapper
#
# Next step is to tell TCAV how to communicate with your model. See `model.GoogleNetWrapper_public ` for details.
#
# You can define a subclass of ModelWrapper abstract class to do this. Let me walk you thru what each function does (tho they are pretty self-explanatory).  This wrapper includes a lot of the functions that you already have, for example, `get_prediction`.
#
# ### 1. Tensors from the graph: bottleneck tensors and ends
# First, store your bottleneck tensors in `self.bottlenecks_tensors` as a dictionary. You only need bottlenecks that you are interested in running TCAV with. Similarly, fill in `self.ends` dictionary with `input`, `logit` and `prediction` tensors.
#
# ### 2. Define loss
# Get your loss tensor, and assigned it to `self.loss`. This is what TCAV uses to take directional derivatives.
#
# While doing so, you would also want to set
# ```python
# self.y_input
# ```
# this simply is a tensorflow place holder for the target index in the logit layer (e.g., 0 index for a dog, 1 for a cat).
# For multi-class classification, typically something like this works:
#
# ```python
# self.y_input = tf.placeholder(tf.int64, shape=[None])
# ```
#
# For example, for a multiclass classifier, something like below would work.
#
# ```python
#     # Construct gradient ops.
#     with g.as_default():
#       self.y_input = tf.placeholder(tf.int64, shape=[None])
#
#       self.pred = tf.expand_dims(self.ends['prediction'][0], 0)
#
#       self.loss = tf.reduce_mean(
#           tf.nn.softmax_cross_entropy_with_logits(
#               labels=tf.one_hot(self.y_input, len(self.labels)),
#               logits=self.pred))
#     self._make_gradient_tensors()
# ```
#
# ### 3. Call _make_gradient_tensors in __init__() of your wrapper
# ```python
# _make_gradient_tensors()
# ```
# does what you expect - given the loss and bottleneck tensors defined above, it adds gradient tensors.
#
# ### 4. Fill in labels, image shapes and a model name.
# Get the mapping from labels (strings) to indice in the logit layer (int) in a dictionary format.
#
# ```python
# def id_to_label(self, idx)
# def label_to_id(self, label)
# ```
#
# Set your input image shape at  `self.image_shape`
#
#
# Set your model name to `self.model_name`
#
# You are done with writing the model wrapper! I wrote two model wrapers, InceptionV3 and Googlenet.

# %% [markdown]
# **sess**: a tensorflow session.

# %%
sess = utils.create_session()

# GRAPH_PATH is where the trained model is stored.
GRAPH_PATH = source_dir + "/inception5h/tensorflow_inception_graph.pb"
# LABEL_PATH is where the labels are stored. Each line contains one class, and they are ordered with respect to their index in 
# the logit layer. (yes, id_to_label function in the model wrapper reads from this file.)
# For example, imagenet_comp_graph_label_strings.txt looks like:
# dummy                                                                                      
# kit fox
# English setter
# Siberian husky ...

LABEL_PATH = source_dir + "/inception5h/imagenet_comp_graph_label_strings.txt"

mymodel = model.GoogleNetWrapper_public(sess,
                                        GRAPH_PATH,
                                        LABEL_PATH)
# Out:
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/utils.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/utils.py:45: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:314: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:320: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:302: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# You can choose ['mixed3a', 'mixed3b', 'mixed4a', 'mixed4b', 'mixed4c', 'mixed4d', 'mixed4e', 'mixed5a', 'mixed5b']
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:271: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %% [markdown]
# ## Step 3. Implement a class that returns activations (maybe with caching!)
#
# Lastly, you will implement a class of the ActivationGenerationInterface which TCAV uses to load example data for a given concept or target, call into your model wrapper and return activations. I pulled out this logic outside of mymodel because this step often takes the longest. By making it modular, you can cache your activations and/or parallelize your computations, as I have done in `ActivationGeneratorBase.process_and_load_activations` in `activation_generator.py`.
#
#
# The `process_and_load_activations` method of the activation generator must return a dictionary of activations that has concept or target name as  a first key, and the bottleneck name as a second key. So something like:
#
# ```python
# {concept1: {bottleneck1: [[0.2, 0.1, ....]]},
# concept2: {bottleneck1: [[0.1, 0.02, ....]]},
# target1: {bottleneck1: [[0.02, 0.99, ....]]}
# ```

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=max_examples)

# %% [markdown]
# ## You are ready to run TCAV!
#
# Let's do it.
#
# **num_random_exp**: number of experiments to confirm meaningful concept direction. TCAV will search for this many folders named `random500_0`, `random500_1`, etc. You can alternatively set the `random_concepts` keyword to be a list of folders of random concepts. Run at least 10-20 for meaningful tests.
#
# **random_counterpart**: as well as the above, you can optionally supply a single folder with random images as the "positive set" for statistical testing. Reduces computation time at the cost of less reliable random TCAV scores.

# %%
tf.logging.set_verbosity(tf.logging.INFO)
## only running num_random_exp = 10 to save some time. The paper number are reported for 500 random runs. 
mytcav = tcav.TCAV(sess,
                   target,
                   concepts,
                   bottlenecks,
                   act_generator,
                   alphas,
                   cav_dir=cav_dir,
                   tcav_dir=tcav_dir,
                   num_random_exp=num_random_exp)#10)
print ('This may take a while... Go get coffee!')
results = mytcav.run(run_parallel=False, num_workers=4)
print ('done!')
# Out:
# :running zebra ['random500_48', 'random500_11']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.23529411764705882, 'random500_11': 0.6875, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2514 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_12']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.8235294117647058, 'random500_12': 0.25, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2515 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_13']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.23529411764705882, 'random500_13': 0.5, 'overall': 0.36363636363636365}
# INFO:tensorflow:Running param 2516 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_14']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.11764705882352941, 'random500_14': 0.75, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2517 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_15']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.23529411764705882, 'random500_15': 0.75, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2518 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_16']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.8823529411764706, 'random500_16': 0.0625, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2519 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_17']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.4375, 'random500_17': 0.35294117647058826, 'overall': 0.3939393939393939}
# INFO:tensorflow:Running param 2520 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_18']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.125, 'random500_18': 0.7058823529411765, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2521 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_19']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.5, 'random500_19': 0.5882352941176471, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2522 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_20']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.625, 'random500_20': 0.35294117647058826, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2523 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_21']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.058823529411764705, 'random500_21': 0.875, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2524 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_22']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.375, 'random500_22': 0.5294117647058824, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2525 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_23']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.4117647058823529, 'random500_23': 0.6875, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2526 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_24']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.625, 'random500_24': 0.5882352941176471, 'overall': 0.6060606060606061}
# INFO:tensorflow:Running param 2527 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_25']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.625, 'random500_25': 0.23529411764705882, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2528 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_26']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.5294117647058824, 'random500_26': 0.375, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2529 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_27']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.5882352941176471, 'random500_27': 0.25, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2530 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_28']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.125, 'random500_28': 0.47058823529411764, 'overall': 0.30303030303030304}
# INFO:tensorflow:Running param 2531 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_29']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.625, 'random500_29': 0.5882352941176471, 'overall': 0.6060606060606061}
# INFO:tensorflow:Running param 2532 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_30']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.1875, 'random500_30': 0.6470588235294118, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2533 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_31']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.11764705882352941, 'random500_31': 0.6875, 'overall': 0.3939393939393939}
# INFO:tensorflow:Running param 2534 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_32']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.6470588235294118, 'random500_32': 0.4375, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2535 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_33']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.3125, 'random500_33': 0.5294117647058824, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2536 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_34']
# INFO:tensorflow:CAV accuracies: {'random500_48': 1.0, 'random500_34': 0.0, 'overall': 0.5151515151515151}
# INFO:tensorflow:Running param 2537 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_35']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.5882352941176471, 'random500_35': 0.375, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2538 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_36']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.5625, 'random500_36': 0.4117647058823529, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2539 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_37']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.23529411764705882, 'random500_37': 0.75, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2540 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_38']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.8235294117647058, 'random500_38': 0.125, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2541 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_39']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.4375, 'random500_39': 0.17647058823529413, 'overall': 0.30303030303030304}
# INFO:tensorflow:Running param 2542 of 2600
# INFO:tensorflow:running zebra ['random500_48', 'random500_40']
# INFO:tensorflow:CAV accuracies: {'random500_48': 0.
 'overall': 0.6060606060606061}
# INFO:tensorflow:Running param 2581 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_30']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.35294117647058826, 'random500_30': 0.5625, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2582 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_31']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.4375, 'random500_31': 0.5882352941176471, 'overall': 0.5151515151515151}
# INFO:tensorflow:Running param 2583 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_32']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.47058823529411764, 'random500_32': 0.5, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2584 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_33']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.11764705882352941, 'random500_33': 0.75, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2585 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_34']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.23529411764705882, 'random500_34': 0.625, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2586 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_35']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.23529411764705882, 'random500_35': 0.8125, 'overall': 0.5151515151515151}
# INFO:tensorflow:Running param 2587 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_36']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.625, 'random500_36': 0.23529411764705882, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2588 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_37']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.23529411764705882, 'random500_37': 0.8125, 'overall': 0.5151515151515151}
# INFO:tensorflow:Running param 2589 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_38']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.5294117647058824, 'random500_38': 0.375, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2590 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_39']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.5, 'random500_39': 0.5882352941176471, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2591 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_40']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.625, 'random500_40': 0.35294117647058826, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2592 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_41']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.5294117647058824, 'random500_41': 0.375, 'overall': 0.45454545454545453}
# INFO:tensorflow:Running param 2593 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_42']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.29411764705882354, 'random500_42': 0.5625, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2594 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_43']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.5, 'random500_43': 0.7058823529411765, 'overall': 0.6060606060606061}
# INFO:tensorflow:Running param 2595 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_44']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.35294117647058826, 'random500_44': 0.75, 'overall': 0.5454545454545454}
# INFO:tensorflow:Running param 2596 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_45']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.5294117647058824, 'random500_45': 0.6875, 'overall': 0.6060606060606061}
# INFO:tensorflow:Running param 2597 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_46']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.6875, 'random500_46': 0.29411764705882354, 'overall': 0.48484848484848486}
# INFO:tensorflow:Running param 2598 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_47']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.35294117647058826, 'random500_47': 0.5, 'overall': 0.42424242424242425}
# INFO:tensorflow:Running param 2599 of 2600
# INFO:tensorflow:running zebra ['random500_49', 'random500_48']
# INFO:tensorflow:CAV accuracies: {'random500_49': 0.1875, 'random500_48': 0.8235294117647058, 'overall': 0.5151515151515151}
# INFO:tensorflow:Done running 2600 params. Took 5028.7275178432465 seconds...
# done!

# %%
utils_plot.plot_results(results, num_random_exp=num_random_exp)
# Out:
# 5, 0.82, 0.86, 0.52, 0.56, 0.68, 0.8, 0.84, 0.74, 0.5, 0.86, 0.72, 0.76, 0.78, 0.82, 0.52, 0.78, 0.66, 0.72, 0.6, 0.32, 0.5, 0.24, 0.54, 0.28, 0.46, 0.56, 0.64, 0.84, 0.68, 0.82, 0.58, 0.62, 0.8, 0.8, 0.88, 0.66, 0.54, 0.7, 0.48, 0.4, 0.78, 0.72, 0.8, 0.76, 0.92, 0.34, 0.78, 0.76, 0.44, 0.72, 0.82, 0.44, 0.54, 0.88, 0.56, 0.54, 0.86, 0.56, 0.92, 0.74, 0.38, 0.8, 0.92, 0.68, 0.54, 0.58, 0.82, 0.42, 0.86, 0.62, 0.52, 0.54, 0.48, 0.44, 0.34, 0.48, 0.34, 0.82, 0.9, 0.48, 0.84, 0.76, 0.68, 0.86, 0.44, 0.56, 0.5, 0.8, 0.42, 0.68, 0.86, 0.8, 0.92, 0.82, 0.6, 0.6, 0.72, 0.78, 0.88, 0.82, 0.62, 0.66, 0.8, 0.54, 0.6, 0.7, 0.36, 0.72, 0.84, 0.66, 0.76, 0.78, 0.74, 0.6, 0.82, 0.74, 0.5, 0.82, 0.78, 0.44, 0.84, 0.56, 0.92, 0.44, 0.42, 0.56, 0.8, 0.68, 0.68, 0.7, 0.78, 0.8, 0.86, 0.48, 0.8, 0.82, 0.56, 0.54, 0.86, 0.58, 0.44, 0.82, 