# %% [markdown]
# # Running TCAV
#
#
# This notebook walks you through things you need to run TCAV.
#
# Before running this notebook, run the following to download all the data.
#
# ```
# cd tcav/tcav_examples/image_models/imagenet
#
# python download_and_make_datasets.py --source_dir=YOUR_PATH --number_of_images_per_folder=50 --number_of_random_folders=3
# ```
#
# In high level, you need:
#
# 1. **example images in each folder** (you have this if you ran the above)
#  * images for each concept
#  * images for the class/labels of interest
#  * random images that will be negative examples when learning CAVs (images that probably don't belong to any concepts)
# 2. **model wrapper** (below uses example from tcav/model.py)
#  * an instance of  ModelWrapper abstract class (in model.py). This tells TCAV class (tcav.py) how to communicate with your model (e.g., getting internal tensors)
# 3. **act_generator** (below uses example from tcav/activation_generator.py)
#  * an instance of ActivationGeneratorInterface that tells TCAV class how to load example data and how to get activations from the model
#
#
# ## Requirements
#
#     pip install the tcav and tensorflow packages (or tensorflow-gpu if using GPU)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tcav.activation_generator as act_gen
import tcav.cav as cav
import tcav.model  as model
import tcav.tcav as tcav
import tcav.utils as utils
import tcav.utils_plot as utils_plot # utils_plot requires matplotlib
import os 
import tensorflow as tf
from config import root_dir, model_to_run, bottlenecks, target, concepts, version

# %% [markdown]
# ## Step 1. Store concept and target class images to local folders
#
# and tell TCAV where they are.
#
# **source_dir**: where images of concepts, target class and random images (negative samples when learning CAVs) live. Each should be a sub-folder within this directory.
#
# Note that random image directories can be in any name. In this example, we are using `random500_0`, `random500_1`,.. for an arbitrary reason.
#
# You need roughly 50-200 images per concept and target class (10-20 pictures also tend to work, but 200 is pretty safe).
#
#
# **cav_dir**: directory to store CAVs (`None` if you don't want to store)
#
# **target, concept**: names of the target class (that you want to investigate) and concepts (strings) - these are folder names in source_dir
#
# **bottlenecks**: list of bottleneck names (intermediate layers in your model) that you want to use for TCAV. These names are defined in the model wrapper below.

# %%
# function to create project name

def list_string(list):
    str = list[0]
    for s in list[1:]:
        str += '_' + s
    return str

def create_project_name(model, bottlenecks, target, concepts, version):
    name = model_to_run
    name += '_'+ list_string(bottlenecks)
    name += ':'+ target
    name += ':'+ list_string(concepts)
    name += '_'+ str(version)
    return name

# %%
print ('REMEMBER TO UPDATE YOUR_PATH (where images, models are)!')
# the name of the parent directory that results are stored (only if you want to cache)
project_name = create_project_name(model_to_run, bottlenecks, target, concepts, version)
working_dir = root_dir + 'log/'  + project_name
# where activations are stored (only if your act_gen_wrapper does so)
activation_dir =  working_dir+ '/activations/'
# where CAVs are stored. 
# You can say None if you don't wish to store any.
cav_dir = working_dir + '/cavs/'
# where CAVs are stored. 
tcav_dir = working_dir + '/tcavs/'
# where the images live. 
source_dir = root_dir + 'tcav/dataset/for_tcav/'
      
utils.make_dir_if_not_exists(activation_dir)
utils.make_dir_if_not_exists(working_dir)
utils.make_dir_if_not_exists(cav_dir)
utils.make_dir_if_not_exists(tcav_dir)

# this is a regularizer penalty parameter for linear classifier to get CAVs. 
alphas = [0.1]   

print('TCAV dataset path is {}'.format(source_dir))
print('Results is saved at {}'.format(working_dir))
# Out:
# REMEMBER TO UPDATE YOUR_PATH (where images, models are)!
# TCAV dataset path is /home/tomohiro/code/tcav/tcav/dataset/for_tcav/
# Results is saved at /home/tomohiro/code/tcav/log/GoogleNet_mixed4c:zebra:dotted_striped_zigzagged_0

# %% [markdown]
# ## Step 2. Write your model wrapper
#
# Next step is to tell TCAV how to communicate with your model. See `model.GoogleNetWrapper_public ` for details.
#
# You can define a subclass of ModelWrapper abstract class to do this. Let me walk you thru what each function does (tho they are pretty self-explanatory).  This wrapper includes a lot of the functions that you already have, for example, `get_prediction`.
#
# ### 1. Tensors from the graph: bottleneck tensors and ends
# First, store your bottleneck tensors in `self.bottlenecks_tensors` as a dictionary. You only need bottlenecks that you are interested in running TCAV with. Similarly, fill in `self.ends` dictionary with `input`, `logit` and `prediction` tensors.
#
# ### 2. Define loss
# Get your loss tensor, and assigned it to `self.loss`. This is what TCAV uses to take directional derivatives.
#
# While doing so, you would also want to set
# ```python
# self.y_input
# ```
# this simply is a tensorflow place holder for the target index in the logit layer (e.g., 0 index for a dog, 1 for a cat).
# For multi-class classification, typically something like this works:
#
# ```python
# self.y_input = tf.placeholder(tf.int64, shape=[None])
# ```
#
# For example, for a multiclass classifier, something like below would work.
#
# ```python
#     # Construct gradient ops.
#     with g.as_default():
#       self.y_input = tf.placeholder(tf.int64, shape=[None])
#
#       self.pred = tf.expand_dims(self.ends['prediction'][0], 0)
#
#       self.loss = tf.reduce_mean(
#           tf.nn.softmax_cross_entropy_with_logits(
#               labels=tf.one_hot(self.y_input, len(self.labels)),
#               logits=self.pred))
#     self._make_gradient_tensors()
# ```
#
# ### 3. Call _make_gradient_tensors in __init__() of your wrapper
# ```python
# _make_gradient_tensors()
# ```
# does what you expect - given the loss and bottleneck tensors defined above, it adds gradient tensors.
#
# ### 4. Fill in labels, image shapes and a model name.
# Get the mapping from labels (strings) to indice in the logit layer (int) in a dictionary format.
#
# ```python
# def id_to_label(self, idx)
# def label_to_id(self, label)
# ```
#
# Set your input image shape at  `self.image_shape`
#
#
# Set your model name to `self.model_name`
#
# You are done with writing the model wrapper! I wrote two model wrapers, InceptionV3 and Googlenet.

# %% [markdown]
# **sess**: a tensorflow session.

# %%
sess = utils.create_session()

# GRAPH_PATH is where the trained model is stored.
GRAPH_PATH = source_dir + "/inception5h/tensorflow_inception_graph.pb"
# LABEL_PATH is where the labels are stored. Each line contains one class, and they are ordered with respect to their index in 
# the logit layer. (yes, id_to_label function in the model wrapper reads from this file.)
# For example, imagenet_comp_graph_label_strings.txt looks like:
# dummy                                                                                      
# kit fox
# English setter
# Siberian husky ...

LABEL_PATH = source_dir + "/inception5h/imagenet_comp_graph_label_strings.txt"

mymodel = model.GoogleNetWrapper_public(sess,
                                        GRAPH_PATH,
                                        LABEL_PATH)
# Out:
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/utils.py:41: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/utils.py:45: The name tf.InteractiveSession is deprecated. Please use tf.compat.v1.InteractiveSession instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:314: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:320: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:302: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# You can choose ['mixed3a', 'mixed3b', 'mixed4a', 'mixed4b', 'mixed4c', 'mixed4d', 'mixed4e', 'mixed5a', 'mixed5b']
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/model.py:271: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %% [markdown]
# ## Step 3. Implement a class that returns activations (maybe with caching!)
#
# Lastly, you will implement a class of the ActivationGenerationInterface which TCAV uses to load example data for a given concept or target, call into your model wrapper and return activations. I pulled out this logic outside of mymodel because this step often takes the longest. By making it modular, you can cache your activations and/or parallelize your computations, as I have done in `ActivationGeneratorBase.process_and_load_activations` in `activation_generator.py`.
#
#
# The `process_and_load_activations` method of the activation generator must return a dictionary of activations that has concept or target name as  a first key, and the bottleneck name as a second key. So something like:
#
# ```python
# {concept1: {bottleneck1: [[0.2, 0.1, ....]]},
# concept2: {bottleneck1: [[0.1, 0.02, ....]]},
# target1: {bottleneck1: [[0.02, 0.99, ....]]}
# ```

# %%
act_generator = act_gen.ImageActivationGenerator(mymodel, source_dir, activation_dir, max_examples=50)

# %% [markdown]
# ## You are ready to run TCAV!
#
# Let's do it.
#
# **num_random_exp**: number of experiments to confirm meaningful concept direction. TCAV will search for this many folders named `random500_0`, `random500_1`, etc. You can alternatively set the `random_concepts` keyword to be a list of folders of random concepts. Run at least 10-20 for meaningful tests.
#
# **random_counterpart**: as well as the above, you can optionally supply a single folder with random images as the "positive set" for statistical testing. Reduces computation time at the cost of less reliable random TCAV scores.

# %%
tf.logging.set_verbosity(tf.logging.INFO)
num_random_exp=50
## only running num_random_exp = 10 to save some time. The paper number are reported for 500 random runs. 
mytcav = tcav.TCAV(sess,
                   target,
                   concepts,
                   bottlenecks,
                   act_generator,
                   alphas,
                   cav_dir=cav_dir,
                   tcav_dir=tcav_dir,
                   num_random_exp=num_random_exp)#10)
print ('This may take a while... Go get coffee!')
results = mytcav.run(run_parallel=False, num_workers=4)
print ('done!')
# Out:
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/tcav.py:408: The name tf.logging.debug is deprecated. Please use tf.compat.v1.logging.debug instead.
#
# This may take a while... Go get coffee!
# WARNING:tensorflow:From /home/tomohiro/code/tcav/tcav/tcav.py:219: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:running 2600 params
# INFO:tensorflow:training with alpha=[0.1]
# INFO:tensorflow:running zebra ['dotted', 'random500_0']
# INFO:tensorflow:running zebra ['dotted', 'random500_1']
# INFO:tensorflow:running zebra ['dotted', 'random500_2']
# INFO:tensorflow:running zebra ['dotted', 'random500_3']
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_2/IEkVtLZ3.jpg
# INFO:tensorflow:cannot identify image file <tensorflow.python.platform.gfile.GFile object at 0x7fae20026e50>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9393939393939394, 'random500_0': 1.0, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_2': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_3': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_4']
# INFO:tensorflow:Finished running param 1 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_5']
# INFO:tensorflow:Finished running param 2 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_6']
# INFO:tensorflow:Finished running param 3 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_6/E7YdjxXE.jpg
# INFO:tensorflow:image file is truncated (63 bytes not processed)
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_4': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_7']
# INFO:tensorflow:Finished running param 4 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_7/BYZQHZZ6.jpg
# INFO:tensorflow:cannot identify image file <tensorflow.python.platform.gfile.GFile object at 0x7fadf006df10>
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_5': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_6': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_7': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_8']
# INFO:tensorflow:Finished running param 5 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_9']
# INFO:tensorflow:running zebra ['dotted', 'random500_10']
# INFO:tensorflow:Finished running param 6 of 2600
# INFO:tensorflow:Finished running param 7 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9393939393939394, 'random500_8': 1.0, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_11']
# INFO:tensorflow:Finished running param 8 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_9': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_12']
# INFO:tensorflow:Finished running param 9 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_13']
# INFO:tensorflow:running zebra ['dotted', 'random500_14']
# INFO:tensorflow:Finished running param 10 of 2600
# INFO:tensorflow:Finished running param 11 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_12': 0.9696969696969697, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_15']
# INFO:tensorflow:Finished running param 12 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_13': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_16']
# INFO:tensorflow:Finished running param 13 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_17']
# INFO:tensorflow:running zebra ['dotted', 'random500_18']
# INFO:tensorflow:Finished running param 14 of 2600
# INFO:tensorflow:Finished running param 15 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9393939393939394, 'random500_16': 1.0, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_19']
# INFO:tensorflow:Finished running param 16 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_19/TWKzjetI.jpg
# INFO:tensorflow:cannot identify image file <tensorflow.python.platform.gfile.GFile object at 0x7fad900c1b10>
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_17': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_19': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_20']
# INFO:tensorflow:Finished running param 17 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_21']
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_20': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_22']
# INFO:tensorflow:Finished running param 18 of 2600
# INFO:tensorflow:Finished running param 19 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_23']
# INFO:tensorflow:Finished running param 20 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9393939393939394, 'random500_21': 1.0, 'overall': 0.9696969696969697}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_22': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_23': 0.9696969696969697, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_24']
# INFO:tensorflow:Finished running param 21 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_25']
# INFO:tensorflow:Finished running param 22 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_24': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_26']
# INFO:tensorflow:Finished running param 23 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_27']
# INFO:tensorflow:Finished running param 24 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_27/XrnNaTjR.jpg
# INFO:tensorflow:reached end of file
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_25': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9090909090909091, 'random500_27': 1.0, 'overall': 0.9545454545454546}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_26': 0.9393939393939394, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_28']
# INFO:tensorflow:Finished running param 25 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_28': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_29']
# INFO:tensorflow:Finished running param 26 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_30']
# INFO:tensorflow:Finished running param 27 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_31']
# INFO:tensorflow:Finished running param 28 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_29/1e5KAB40.jpg
# INFO:tensorflow:image file is truncated (63 bytes not processed)
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_29': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_30': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_31': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_32']
# INFO:tensorflow:Finished running param 29 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_32': 0.9696969696969697, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_33']
# INFO:tensorflow:Finished running param 30 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_33/WWAAzIZ5.jpg
# INFO:tensorflow:image file is truncated (56 bytes not processed)
# INFO:tensorflow:running zebra ['dotted', 'random500_34']
# INFO:tensorflow:Finished running param 31 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_34/hG7JPrQ0.jpg
# INFO:tensorflow:image file is truncated (42 bytes not processed)
# INFO:tensorflow:running zebra ['dotted', 'random500_35']
# INFO:tensorflow:Finished running param 32 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_33': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_36']
# INFO:tensorflow:Finished running param 33 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_36/Z3XnACWb.jpg
# INFO:tensorflow:image file is truncated (19 bytes not processed)
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_34': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_35': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_36': 0.9393939393939394, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['dotted', 'random500_37']
# INFO:tensorflow:Finished running param 34 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_38']
# INFO:tensorflow:Finished running param 35 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_38/uFqSUvGu.jpg
# INFO:tensorflow:image file is truncated (3 bytes not processed)
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_37': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_39']
# INFO:tensorflow:Finished running param 36 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_38': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_40']
# INFO:tensorflow:Finished running param 37 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_39': 0.9090909090909091, 'overall': 0.9545454545454546}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_40': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_41']
# INFO:tensorflow:Finished running param 38 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_42']
# INFO:tensorflow:Finished running param 39 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_41': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_42': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_43']
# INFO:tensorflow:running zebra ['dotted', 'random500_44']
# INFO:tensorflow:Finished running param 40 of 2600
# INFO:tensorflow:Finished running param 41 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_45']
# INFO:tensorflow:Finished running param 42 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_44': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_43': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['dotted', 'random500_46']
# INFO:tensorflow:Finished running param 43 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 0.9696969696969697, 'random500_45': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_46': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['dotted', 'random500_47']
# INFO:tensorflow:Finished running param 44 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_48']
# INFO:tensorflow:Finished running param 45 of 2600
# INFO:tensorflow:running zebra ['dotted', 'random500_49']
# INFO:tensorflow:Finished running param 46 of 2600
# /home/tomohiro/code/tcav/tcav/dataset/for_tcav/random500_49/DdNwgeWO.jpg
# INFO:tensorflow:cannot identify image file <tensorflow.python.platform.gfile.GFile object at 0x7facb4041250>
# INFO:tensorflow:running zebra ['striped', 'random500_0']
# INFO:tensorflow:Finished running param 47 of 2600
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_47': 1.0, 'overall': 1.0}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_48': 0.9090909090909091, 'overall': 0.9545454545454546}
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_0': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:CAV accuracies: {'dotted': 1.0, 'random500_49': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_1']
# INFO:tensorflow:Finished running param 48 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_1': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_2']
# INFO:tensorflow:Finished running param 49 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_2': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_3']
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_3': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_4']
# INFO:tensorflow:Finished running param 50 of 2600
# INFO:tensorflow:Finished running param 51 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_4': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_5']
# INFO:tensorflow:Finished running param 52 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_5': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['striped', 'random500_6']
# INFO:tensorflow:Finished running param 53 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_6': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_7']
# INFO:tensorflow:Finished running param 54 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_7': 0.9393939393939394, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['striped', 'random500_8']
# INFO:tensorflow:Finished running param 55 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 0.8484848484848485, 'random500_8': 1.0, 'overall': 0.9242424242424242}
# INFO:tensorflow:running zebra ['striped', 'random500_9']
# INFO:tensorflow:Finished running param 56 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 0.9696969696969697, 'random500_9': 0.9696969696969697, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['striped', 'random500_10']
# INFO:tensorflow:Finished running param 57 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_10': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_11']
# INFO:tensorflow:Finished running param 58 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_11': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_12']
# INFO:tensorflow:Finished running param 59 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 0.9696969696969697, 'random500_12': 0.9696969696969697, 'overall': 0.9696969696969697}
# INFO:tensorflow:running zebra ['striped', 'random500_13']
# INFO:tensorflow:Finished running param 60 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_13': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['striped', 'random500_14']
# INFO:tensorflow:Finished running param 61 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_14': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_15']
# INFO:tensorflow:Finished running param 62 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_15': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_16']
# INFO:tensorflow:Finished running param 63 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 0.9696969696969697, 'random500_16': 1.0, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['striped', 'random500_17']
# INFO:tensorflow:Finished running param 64 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_17': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['striped', 'random500_18']
# INFO:tensorflow:Finished running param 65 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_18': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_19']
# INFO:tensorflow:Finished running param 66 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 0.9696969696969697, 'random500_19': 0.9090909090909091, 'overall': 0.9393939393939394}
# INFO:tensorflow:running zebra ['striped', 'random500_20']
# INFO:tensorflow:Finished running param 67 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_20': 0.9696969696969697, 'overall': 0.9848484848484849}
# INFO:tensorflow:running zebra ['striped', 'random500_21']
# INFO:tensorflow:Finished running param 68 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_21': 1.0, 'overall': 1.0}
# INFO:tensorflow:running zebra ['striped', 'random500_22']
# INFO:tensorflow:Finished running param 69 of 2600
# INFO:tensorflow:CAV accuracies: {'striped': 1.0, 'random500_22': 0.9393939393939394, 'overall': 0.9696969696969697}

# %%
utils_plot.plot_results(results, num_random_exp=num_random_exp)
